# %% [markdown]
# # Benchmark
#
# Cartesian products between datasets generated from networks and inference methods
#
# ```mermaid
# graph TD;
#
# subgraph Networks
# n1(("$$n_1$$"))
# n2(("$$n_2$$"))
# end
#
# subgraph Datasets
# d1(("$$d_1$$"))
# d2(("$$d_2$$"))
# d3(("$$d_3$$"))
# end
#
# subgraph Inferences
# i1(("$$i_1$$"))
# i2(("$$i_2$$"))
# end
#
# subgraph n1 scores
# direction LR
# s1(("$$s_1$$"))
# s2(("$$s_2$$"))
# s3(("$$s_3$$"))
# s4(("$$s_4$$"))
# end
# subgraph n2 scores
# s5(("$$s_5$$"))
# s6(("$$s_6$$"))
# end
#
# n1 --> d1 & d2;
# n2 --> d3;
#
# d1 & i1 -.-> s1;
# d1 & i2 -.-> s2;
# d2 & i1 -.-> s3;
# d2 & i2 -.-> s4;
#
# d3 & i1 -.-> s5;
# d3 & i2 -.-> s6;
# ```

# %% [markdown]
# ## Display the registered networks or inference method
#
# To know which networks or inference methods are available, use the functions
# `available_networks` and `available_inferences`.
# See more informations on how to display and register your own networks
# and inference methods [here](register.ipynb).

# %%
from harissa.benchmark import Benchmark

benchmark = Benchmark(verbose=True)
benchmark.datasets.path='../cardamom_datasets'
benchmark.networks.include=['BN8', 'FN4', 'FN8', 'CN5']

benchmark.save('../cardamom_benchmark')
# Out:
# PosixPath('/home/nseyler/Work/benchmark/notebooks/../cardamom_benchmark')
